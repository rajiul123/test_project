# %% [markdown]
# <a href="https://colab.research.google.com/github/rajiul123/test_project/blob/main/basic_project_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9edc4055-82fd-47b7-8bb0-12c9e6ee5e41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9edc4055-82fd-47b7-8bb0-12c9e6ee5e41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("online.csv")

# %%
df.shape
# Out:
# (50, 5)

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# **Seperating X & y**

# %%
X = df.drop(["Profit"], axis=1)

# %%
X.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y = df["Profit"]

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %% [markdown]
# **Encoding**

# %%
city = pd.get_dummies(X["Area"], drop_first=True, dtype=int)

# %%
city.head()
# Out:
#    Dhaka  Rangpur
# 0      1        0
# 1      0        0
# 2      0        1
# 3      1        0
# 4      0        1

# %%
X = X.drop(["Area"], axis=1)

# %%
X.head()
# Out:
#    Marketing Spend  Administration  Transport
# 0        114523.61       136897.80  471784.10
# 1        162597.70       151377.59  443898.53
# 2        153441.51       101145.55  407934.54
# 3        144372.41       118671.85  383199.62
# 4        142107.34        91391.77  366168.42

# %%
X = pd.concat([X, city], axis=1)

# %%
X.head()
# Out:
#    Marketing Spend  Administration  Transport  Dhaka  Rangpur
# 0        114523.61       136897.80  471784.10      1        0
# 1        162597.70       151377.59  443898.53      0        0
# 2        153441.51       101145.55  407934.54      0        1
# 3        144372.41       118671.85  383199.62      1        0
# 4        142107.34        91391.77  366168.42      0        1

# %% [markdown]
# **Spliting Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# **Training Data**

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# 33     96778.92
# 35     96479.51
# 26    105733.54
# Name: Profit, dtype: float64

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([103501.0825284 , 128011.28068627, 126695.43891127,  70573.91718775,
#        173381.96874259, 124238.07860872,  69298.09250304,  98399.41936876,
#        116419.1480864 , 161430.98134847,  94740.73303076,  89920.22800514,
#        105956.86065332])

# %%
regressor.score(X_test, y_test)
# Out:
# 0.884097862392347

# %% [markdown]
# **R Squared Value**

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.884097862392347
